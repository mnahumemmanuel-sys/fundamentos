# %% [markdown]
# <a href="https://colab.research.google.com/github/mnahumemmanuel-sys/fundamentos/blob/main/Unidad-1/programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad = int(input("¿que edad tienes? "))
if edad >= 0 and edad <= 6
  print ("eres un bebe")
elif edad >= 7 and edad <= 12
  print ("eres un niño")
elif edad >= 13 and edad <= 18
  print ("eres un adolescente")
elif edad >= 19 and edad <= 30
  print ("eres un adulto joven")
elif edad >= 31 and edad <= 65
  print ("eres un adulto")
elif edad >= 66
  print ("eres un anciano")
else:
  print ("edad incorrecta")
# Out:
# ¿que edad tienes? 6
# eres un menor de edad

# %%
base = input("Dame la base del triangulo ")
altura = input("Dame la altura del trianguo ")
area = (int(base)*int(altura))/2
print("el area del triangulo es", float(area))
# Out:
# Dame la base del triangulo 7
# Dame la altura del trianguo 5
# el area del triangulo es 17.5

# %%
z = 10
a = "hola"
print(z*a)
# Out:
# holaholaholaholaholaholaholaholaholahola

# %%
numero1 = 20
numero2 = 40
if numero1 > numero2:
  print("El numero", numero1, "es mayor que", numero2)
else:
  print("El numero", numero2, "es mayor que", numero1)
# Out:
# El numero 40 es mayor que 20

# %%
edad = int(input("Dame tu edad "))
if edad <= 10:
  print("eres un niño")
elif edad >= 11 and  edad<= 17 :
  print("eres un adolescente")
elif edad >= 18 and edad <=30 :
  print("eres un adulto joven")
elif edad >= 31 and edad <= 64 :
  print("Eres un adulto")
else:
  print("Eres un mayor de edad")
# Out:
# Dame tu edad 80
# Eres un mayor de edad

# %%
edad = int(input("Dame tu edad "))
if edad >= 66:
  print("Eres un adulto mayor")
elif edad >= 65 and edad<= 31:
  print("Eres un adulto")
elif edad >= 30 and edad <= 18:
  print("Eres un adulto joven")
elif edad >= 17 and edad <= 11:
  print("Eres un adolescente")
else:
  print("Eres un niño")
# Out:
# Dame tu edad 2
# Eres un niño

# %%
tabla = 5
for i in range(1,11,2):
  print(tabla,"x",i,"=",tabla*i)
# Out:
# 5 x 1 = 5
# 5 x 3 = 15
# 5 x 5 = 25
# 5 x 7 = 35
# 5 x 9 = 45

# %%
tabla = int(input("Dame la tabla de multiplicar que quieres ver "))
v1 = int(input("Dame el primer valor "))
v2 = int(input("Dame el segundo valor "))
while v2 <= v1:
  print("El primer valor debe ser menor que el segundo")
  v2 = int(input("Dame el segundo valor "))
v3 = int(input("Dame el tercer valor "))
for i in range(v1,v2,v3):
  print(tabla,"x",i,"=",tabla*i)
# Out:
# Dame la tabla de multiplicar que quieres ver 10
# Dame el primer valor 10
# Dame el segundo valor 10
# El primer valor debe ser menor que el segundo
# Dame el segundo valor 10
# El primer valor debe ser menor que el segundo
# Dame el segundo valor 10
# El primer valor debe ser menor que el segundo
# Dame el segundo valor 9
# El primer valor debe ser menor que el segundo
# Dame el segundo valor 9
# El primer valor debe ser menor que el segundo
# Dame el segundo valor 9
# El primer valor debe ser menor que el segundo
# Dame el segundo valor 20
# Dame el tercer valor 1
# 10 x 10 = 100
# 10 x 11 = 110
# 10 x 12 = 120
# 10 x 13 = 130
# 10 x 14 = 140
# 10 x 15 = 150
# 10 x 16 = 160
# 10 x 17 = 170
# 10 x 18 = 180
# 10 x 19 = 190

# %% [markdown]
# # **Tema de listas**

# %%
alumnos = ["Ana", "Luis", "Carlos", "Juan"]
print(alumnos)
print(alumnos[0])
print(alumnos[3])
# Out:
# ['Ana', 'Luis', 'Carlos', 'Juan']
# Ana
# Juan

# %%
alumnos[1] = "Maria Luisa"
print(alumnos)
# Out:
# ['Ana', 'Maria Luisa', 'Carlos', 'Juan']

# %%
alumnos.append("Karla")
print(alumnos)
# Out:
# ['Ana', 'Maria Luisa', 'Carlos', 'Juan', 'Karla']

# %%
alumnos.insert(2, "Cristina")
print(alumnos)
# Out:
# ['Ana', 'Maria Luisa', 'Cristina', 'Carlos', 'Juan', 'Karla']

# %%
alumnos.remove("Ana")
print(alumnos)
# Out:
# ['Maria Luisa', 'Cristina', 'Carlos', 'Juan', 'Karla']

# %%
alumnos.pop(2)
print(alumnos)
# Out:
# ['Maria Luisa', 'Cristina', 'Juan', 'Karla']

# %%
del alumnos[3]
print(alumnos)
# Out:
# ['Maria Luisa', 'Cristina', 'Juan']

# %%
print("Elementos en la lista de alumnos", len(alumnos))
# Out:
# Elementos en la lista de alumnos 3

# %%
alumnos.append("Ana")
alumnos.append("Hernesto")
for x in alumnos:
  print(x)
# Out:
# Maria Luisa
# Cristina
# Juan
# Ana
# Hernesto
# Ana
# Hernesto
# Ana
# Hernesto
# Ana
# Hernesto
# Ana
# Hernesto
# Ana
# Hernesto
# Ana
# Hernesto

# %%
print(alumnos)
for x in alumnos:
  print(x)
  if x == "Ana":
    break
# Out:
# ['Maria Luisa', 'Cristina', 'Juan', 'Ana', 'Hernesto', 'Ana', 'Hernesto', 'Ana', 'Hernesto', 'Ana', 'Hernesto', 'Ana', 'Hernesto', 'Ana', 'Hernesto', 'Ana', 'Hernesto']
# Maria Luisa
# Cristina
# Juan
# Ana

# %%
software = ["Python", "Python y VS code", "AutoCAD", "SolidWorks", "Java"]
print(software)
# Out:
# ['Python', 'Python y VS code', 'AutoCAD', 'SolidWorks', 'Java']

# %%
for i in range( len(software)):
  print(software[i])

print("Enlistar otra vez la lista")
for x in software:
  print(x)
